# %% [markdown]
# Homework 2

# %% [markdown]
# Bài 1 : Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a , b = map(int, input().split())
chu_vi = (a+b)*2
dien_tich = a*b 
print(f"{chu_vi}\n{dien_tich}")
# Out:
# 18
# 20

# %% [markdown]
# Bài 2 : Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
import math
R = float(input())
chu_vi = 2 * math.pi * R 
dien_tich = R * (math.pi**2)
print(f"{chu_vi}\n{dien_tich}")
# Out:
# 31.41592653589793
# 49.34802200544679

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn

# %%
a , b , c = map(int , input().split())   
if  a+b>c and a+c>b and b+c>a :   
    if a==b==c : 
        print('Đây là tam giác đều')
    elif a == b or b ==c or a == c : 
        print ('Đây là tam giác cân')
    elif (a**2) + (b**2) == (c**2) or (a**2)+(c**2) == (b**2) or (b**2)+(c**2) == (a**2) :
         print('Đây là tam giác vuông')
    else:
         print('Đây là tam giác thường')
else:
    print ('Đây không phải là tam giác')
# Out:
# Đây là tam giác thường

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a , b = map(int,input().split())
x = -b / a
if b == 0 : 
    print ("Phương trình có vô số nghiệm ") 
elif a == 0 : 
    print ("Phương trình vô nghiệm")
else : 
    print (x)
# Out:
# -1.25

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a , b , c ,d , m , n = map(int, input().split())
D = a*d - b*c
Dx = m * d - b * n
Dy = a * n - m * c
x = Dx / D 
y = Dy / D 
if D != 0 :
    if Dx == 0 or Dy == 0 : 
        print ("Phương trình vô số nghiệm")
    else : 
        print (f"Phương trình có nghiệm duy nhất là : {x} va {y}")
else : 
    print ("Phương trình vô nghiệm ")
# Out:
# Phương trình có nghiệm duy nhất là : -4.0 va 4.5

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không

# %%
a , b = map(int, input().split())
c , d = map(int , input().split())
I = (a , b)
A = (c , d)
R = int(input())
IA = ((c-a)**2+(d-b)**2)
if IA > R**2 : 
    print (f"Điểm {A} không thuộc đường tròn")
else : 
    print (f"Điểm {A} thuộc đường tròn")
# Out:
# Điểm (2, 3) thuộc đường tròn

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
import math
a , b ,c = map(int , input().split())
if a == 0 : 
    if b== 0 : 
        if c==0: 
            print ("Phương trình có vô số nghiệm")
else : 
    delta = b**2 - 4*a*c 
    if delta < 0 : 
        print ("Phương trình vô nghiệm ")
    else : 
        x1 = (b - math.sqrt(delta)) / 2 *a 
        x2 = (-b-math.sqrt(delta)) / 2 * a 
        print (f"Phương trình có 2 nghiệm phân biệt là :{x1} va {x2}")
# Out:
# Phương trình vô nghiệm

# %% [markdown]
# Bài 11: Tính x mũ y (Với x, y là số thực)

# %%
x , y = map(int , input().split())
a = x**y 
print (a)
# Out:
# 81

# %% [markdown]
# Nhập vào 1 số nguyên đại diện cho tháng trong năm ( nhuận ).In ra số ngày trong tháng đó

# %%
thang = int(input())
if (thang == 1 or thang == 3 or thang == 5 or thang == 7 or thang == 8 or thang == 10 or thang ==12) : 
    s = f"Thang {thang} có 31 ngày"
elif (thang == 4 or thang == 6 or thang == 9 or thang ==1 ) : 
    s = f"Thang {thang} có 30 ngày"
elif thang == 2 : 
    s = f"Thang {thang} có 29 ngày "
else : 
    s = f"Thang {thang} khong co trong nam "

print (s)
# Out:
# Thang 2 có 29 ngày

# %%
n = int(input())
nam = int(input())

match thang : 
    case 1|3|5|7|10|12 : 
        s = f"Thang {thang } co 31 ngay "
    case 2 :
          if (nam % 4 == 0 and nam % 100 != 0) or nam % 400 == 0 : 
             s = f"Thang {thang } co 29 ngay "
          else : 
                s = f"Thang {thang } co 28 ngay "
    case 4|6|9|11 : 
            s = f"Thang {thang } co 30 ngay "
    case _ : 
              s = f"Thang {thang } khong co trong nam  "

print (s)
